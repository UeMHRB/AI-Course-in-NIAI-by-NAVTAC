# %% [markdown]
# # Task 1: Two Numbers Addition
#
# ## Description
# This task demonstrates basic arithmetic operations in Python by adding two numbers together.
#
# ### What the code does:
# - Initializes two variables with integer values
# - Performs addition operation on both numbers
# - Displays the result in a formatted output string

# %%
num1 = 2
num2 = 3

print(f" Sum of {num1} and {num2} is : {num1 + num2}")
# Out:
#  Sum of 2 and 3 is : 5
